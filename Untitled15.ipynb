# %% [markdown]
# <a href="https://colab.research.google.com/github/lauradela/telecomX_challengeONE/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json'

# %%
#com essa linha eu acesso o arquivo json para começar a extrair os dados da API
response = requests.get(url)
if response.status_code == 200:
  #aqui é uma variavel, não tem que ser estruturada
    dados = response.json()
    # aqui é um daraframe que pode ser exportado e tem estrutura de tabela
    df = pd.DataFrame(dados)
    print(df.head())
else:
  print ("Erro na requisição", response.status_code)
  #chamei o arquivo do github
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# Normalização dos dados

# %%
# 1. Expandindo as colunas com dicionários,transformando cada coluna(normalizando)
df_customer = pd.json_normalize(df['customer'])
df_phone = pd.json_normalize(df['phone'])
df_internet = pd.json_normalize(df['internet'])
df_account = pd.json_normalize(df['account'])

# 2. Juntando tudo num único DataFrame final# df_final = pd.concat() estou salvando temporariamente , preciso salvar em disco
df_final = pd.concat(
    [df[['customerID', 'Churn']], df_customer, df_phone, df_internet, df_account],
    axis=1
)

# %%
# Salvando o DataFrame df_final em um arquivo CSV
df_final.to_csv('df_final.csv', index=False)

# %%
# conferindo o resultado:
df_final = pd.read_csv('df_final.csv')
df_final.head()
#como ficou o dataframe df_final depois de expandir os dicionarios
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %% [markdown]
# Limpeza e Tratamento dos Dados

# %%
# se informando sobre o arquivo
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Charges.Total     7267 non-null   object ,aqui está como object, e ele  é numerico : fazendo a correção:
df_final['Charges.Total'] = pd.to_numeric(df_final['Charges.Total'], errors='coerce')

# %%
##revisando as trocas de informações
df_final.info()
# as 2 últimas linhas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df_final = df_final.dropna(subset=['Churn', 'Charges.Total'])

# %%
# verificando os valores nulos
df_final.isnull().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
df_final.drop('customerID', axis=1, inplace=True)
# removi a coluna customer id
# Out:
# <ipython-input-14-2429500271>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop('customerID', axis=1, inplace=True)

# %%
df_final
# Out:
#      Churn  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       No  Female              0     Yes        Yes       9          Yes
# 1       No    Male              0      No         No       9          Yes
# 2      Yes    Male              0      No         No       4          Yes
# 3      Yes    Male              1     Yes         No      13          Yes
# 4      Yes  Female              1     Yes         No       3          Yes
# ...    ...     ...            ...     ...        ...     ...          ...
# 7262    No  Female              0      No         No      13          Yes
# 7263   Yes    Male              0     Yes         No      22          Yes
# 7264    No    Male              0      No         No       2          Yes
# 7265    No    Male              0     Yes        Yes      67          Yes
# 7266    No    Male              0     Yes        Yes      63           No
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
# Removi as linhas onde 'Charges.Total' é nulo
df_final = df_final.dropna(subset=['Charges.Total'])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
print(df['Churn'].value_counts(dropna=False))
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
df_temp = df.copy()
df_temp['Churn'] = df_temp['Churn'].fillna('Desconhecido')

df_temp['Churn'].value_counts().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    figsize=(6, 6),
    title='Proporção de Churn'
)
plt.ylabel('')
plt.show()

# %%
df_temp = df.copy()
df_temp['Churn'] = df_temp['Churn'].fillna('Desconhecido')

plt.figure(figsize=(8, 5))
ax = sns.countplot(data=df_temp, x='Churn')
plt.title('Distribuição de Churn (incluindo valores ausentes)')
plt.xlabel('Churn')
plt.ylabel('Número de Clientes')

# Adiciona os números em cima das barras
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom')
    plt.show()

# %%
df['Churn'] = df['Churn'].replace('', 'No')

# %%
print(df['Churn'].unique())
# Deve mostrar: ['No' 'Yes']
# Out:
# ['No' 'Yes']

# %%
print(df_final['Churn'].value_counts())
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
# 1. Substituir valores vazios ('') por 'No'
df['Churn'] = df['Churn'].replace('', 'No')

# 2. Mostrar os valores únicos agora
print("Valores únicos em 'Churn' após limpeza:")
print(df['Churn'].unique())

# 3. (Opcional) Mostrar a contagem de cada valor
print("\nContagem de valores em 'Churn':")
print(df['Churn'].value_counts())
# Out:
# Valores únicos em 'Churn' após limpeza:
# ['No' 'Yes']
#
# Contagem de valores em 'Churn':
# Churn
# No     5398
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# 5398 clientes permaneceram (não evadiram)
#
# 1869 clientes saíram (deram churn)

# %%
# preciso saber qual o serviço mais procurado
servicos = ['PhoneService', 'MultipleLines', 'OnlineSecurity',
            'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# Dicionário para guardar os resultados
servico_counts = {}

for servico in servicos:
    count_yes = df_final[df_final[servico] == 'Yes'].shape[0]
    servico_counts[servico] = count_yes  # 👉 adicionar no dicionário
    print(f"{servico}: {count_yes} clientes")

# Transformei em DataFrame e ordenei
# Out:
# PhoneService: 6352 clientes
# MultipleLines: 2967 clientes
# OnlineSecurity: 2015 clientes
# OnlineBackup: 2425 clientes
# DeviceProtection: 2418 clientes
# TechSupport: 2040 clientes
# StreamingTV: 2703 clientes
# StreamingMovies: 2731 clientes

# %%
 # analizando o tenure
df_final['tenure'].max()
# Out:
# 72

# %%
df_final['tenure'].describe()
#pedi uma descrição sobre este periodo
# Out:
# count    7032.000000
# mean       32.421786
# std        24.545260
# min         1.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %% [markdown]
# ** Significado:**
#   **count** Quantos clientes estão na base (número total de linhas)
#   ** mean **Média de meses de permanência dos clientes
#    **std** Desvio padrão (variação dos tempos)
#     **min** Menor tempo de permanência
#     **25% ** Primeiro quartil (25% dos clientes ficaram até esse tempo)
#    ** 50%** Mediana (tempo que divide os clientes ao meio)
#    **  75%** Terceiro quartil (75% ficaram até esse tempo)
#  **max **Maior tempo de permanência —  72 meses(6 anos)

# %% [markdown]
# **Minha conclusão:*
#
# * Num periodo de** 6 anos** somente** 5%** permaneram fiéis a TELECOM X por 72 meses,— ou seja,  ficaram durante todo o período. e o maior numero de clientes, que foi de 9% *permaneceram *1 mes indicando um alto índice de (evasão)churn logo no início quando obtiveram o produto.

# %%
plt.figure(figsize=(10, 6))
df_final['tenure'].hist(bins=72, color='skyblue', edgecolor='black')
plt.xlabel('Meses como cliente')
plt.ylabel('Número de clientes')
plt.title('Distribuição de permanência dos clientes (Tenure)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# O gráfico acima mostra claramente que a maioria dos cancelamentos ocorre no primeiro mês de uso do serviço. A altura da barra no mês 1 revela um alto índice de evasão imediata, indicando **possíveis falhas na experiência inicial** **do cliente**. Já os meses finais demonstram que apenas uma pequena parcela atinge longos períodos de fidelização, reforçando que a retenção inicial** é um ponto crítico a ser melhorado.**

# %%
print(df_final['tenure'].unique())
# Out:
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42]

# %%
tenure_zero = df_final[df_final['tenure'] == 0]
print(f"Número de clientes com tenure = 0: {len(tenure_zero)}")
# Out:
# Número de clientes com tenure = 0: 0

# %%
tenure_zero.head()
# Out:
# Empty DataFrame
# Columns: [Churn, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, Charges.Monthly, Charges.Total]
# Index: []

# %%
tenure_zero = df_final[df_final['tenure'] == 0]
print(f"Número de clientes com tenure = 0: {len(tenure_zero)}")
# Out:
# Número de clientes com tenure = 0: 0

# %%
tenure_zero = df_final[df_final['tenure'] == 0]
print("Antes da limpeza:")
print(f"Número de clientes com tenure = 0: {len(tenure_zero)}")

# Verifiquei valores faltantes
print("Valores faltantes em 'Churn' para tenure=0:", tenure_zero['Churn'].isnull().sum())
print("Valores faltantes em 'Charges.Total' para tenure=0:", tenure_zero['Charges.Total'].isnull().sum())
# Out:
# Antes da limpeza:
# Número de clientes com tenure = 0: 0
# Valores faltantes em 'Churn' para tenure=0: 0
# Valores faltantes em 'Charges.Total' para tenure=0: 0

# %% [markdown]
# Durante a limpeza dos dados (remoção de valores ausentes em Churn e Charges.Total), os 11 clientes com tenure = 0 foram eliminados da base. Inicialmente representavam 0,15% da amostra. Esses casos podem indicar churn precoce, mas não foram incluídos na análise final por serem incompletos.

# %% [markdown]
# introduzindo PhoneService

# %%
df_final['PhoneService'].describe()
# Out:
# count     7032
# unique       2
# top        Yes
# freq      6352
# Name: PhoneService, dtype: object

# %%
df_final['PhoneService'].value_counts()
df_final['PhoneService'].value_counts(normalize=True)  # porcentagem
# Out:
# PhoneService
# Yes    0.903299
# No     0.096701
# Name: proportion, dtype: float64

# %%
print(df_final['PhoneService'].value_counts())
# Out:
# PhoneService
# Yes    6352
# No      680
# Name: count, dtype: int64

# %%
print(df_final['PhoneService'].value_counts(normalize=True) * 100)
# Out:
# PhoneService
# Yes    90.32992
# No      9.67008
# Name: proportion, dtype: float64

# %%
pd.crosstab(df_final['PhoneService'], df_final['Churn'])
# Out:
# Churn           No   Yes
# PhoneService
# No             510   170
# Yes           4653  1699

# %%
pd.crosstab(df_final['PhoneService'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                No        Yes
# PhoneService
# No            75.000000  25.000000
# Yes           73.252519  26.747481

# %%
sns.countplot(data=df_final, x='PhoneService', hue='Churn')
plt.title('Churn por tipo de Phone Service')
plt.xlabel('Phone Service')
plt.ylabel('Número de Clientes')
plt.legend(title='Churn')
plt.show()

# %% [markdown]
# A análise da variável PhoneService indica que 90% dos clientes possuem o serviço. A taxa de churn entre os que têm o serviço (26,75%) é ligeiramente maior do que entre os que não têm (25%). Essa diferença, embora pequena, sugere que o serviço telefônico por si só não é um forte preditor de evasão, mas pode interagir com outras variáveis (como tipo de contrato ou pacote de internet).

# %%
clientes_com_internet = df_final[df_final['InternetService'] != 'No'].shape[0]
print(f"Clientes com algum tipo de Internet: {clientes_com_internet}")
# Out:
# Clientes com algum tipo de Internet: 5512

# %% [markdown]
# Clientes com algum tipo de Internet: 5686
# Conclusão:
#
# O serviço mais utilizado é o Phone Service , com 6.560 clientes .
#
# Entre os serviços digitais, os mais populares são:
#
# Streaming de filmes (2.816 clientes),
#
# StreamingTV (2.790),
#
# e OnlineBackup (2.504).
#
# Notamos também que muitos clientes não utilizam serviços de segurança e suporte como:
#
# OnlineSecurity (2.078 clientes) e
#
# Suporte Técnico (2.104),
#
# o que pode estar relacionado a menor fidelização , já que esses serviços podem aumentar o valor percebido e a satisfação do cliente.
#
# Por fim, a variável InternetService não usa os valores 'Yes' e 'No', mas sim tipos de internet ('DSL', 'Fiber optic', 'No'). Por isso, sua contagem com 'Yes' resultou em zero. Ela deve ser analisada separadamente para entender o perfil de uso da internet pelos clientes.
#
# Por fim, observamos que 5.686 clientes possuem algum tipo de serviço de internet, o que representa uma parte significativa da base.

# %% [markdown]
# Introduzindo InternetService

# %%
df_final['InternetService'].describe()
# Out:
# count            7032
# unique              3
# top       Fiber optic
# freq             3096
# Name: InternetService, dtype: object

# %%
df_final['InternetService'].value_counts()
df_final['InternetService'].value_counts(normalize=True)  # porcentagem
# Out:
# InternetService
# Fiber optic    0.440273
# DSL            0.343572
# No             0.216155
# Name: proportion, dtype: float64

# %%
print(df_final['InternetService'].value_counts())
# Out:
# InternetService
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: count, dtype: int64

# %%
print(df_final['InternetService'].value_counts(normalize=True) * 100)
# Out:
# InternetService
# Fiber optic    44.027304
# DSL            34.357224
# No             21.615472
# Name: proportion, dtype: float64

# %%
pd.crosstab(df_final['InternetService'], df_final['Churn'])
# Out:
# Churn              No   Yes
# InternetService
# DSL              1957   459
# Fiber optic      1799  1297
# No               1407   113

# %%
pd.crosstab(df_final['InternetService'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.001656  18.998344
# Fiber optic      58.107235  41.892765
# No               92.565789   7.434211

# %% [markdown]
# A análise mostra uma forte relação entre o tipo de internet e o churn:
#
# Clientes com Fiber optic apresentam a maior taxa de churn: 41,89% — quase o dobro da média geral.
#
# Já os que usam DSL têm uma taxa significativamente menor: 19,00%.
#
# Clientes que não possuem internet praticamente não cancelam: apenas 7,43% de churn.
#
# Essa diferença pode indicar:
#
# Clientes com Fiber optic têm expectativas mais altas (velocidade, estabilidade) e podem sair mais facilmente se não forem atendidos.
#
# Clientes sem internet tendem a ter menos engajamento com os serviços da empresa, mas também menos razões para cancelar.
#
#
#  fibra óptica, apesar de ser o serviço mais usado, é também o que mais perde clientes.

# %%
sns.countplot(data=df_final, x='InternetService', hue='Churn')
plt.title('Churn por tipo de InternetService')
plt.xlabel('InternetService')
plt.ylabel('Número de Clientes')
plt.legend(title='Churn')
plt.show()

# %% [markdown]
# A variável InternetService apresenta três categorias: Fiber optic (44,07%), DSL (34,22%) e No service (21,71%). A predominância da fibra óptica indica uma base de clientes que busca maior velocidade e desempenho. Clientes que não utilizam internet representam uma parcela significativa e devem ser analisados separadamente, pois seu comportamento em relação ao churn pode ser diferente.

# %% [markdown]
# Análise do serviço de Internet
#
# A maior parte dos clientes utiliza Fiber optic (44%), seguida por DSL (34%), e 21% não possuem serviço de internet.
#
# Ao cruzar com a variável Churn, observamos diferenças importantes:
#
# Clientes com Fiber optic têm a maior taxa de churn: 41,89% cancelaram o serviço.
#
# Clientes com DSL apresentaram churn de 19%, uma taxa significativamente menor.
#
# Clientes sem internet mostraram a menor evasão: apenas 7,43%.
#
# Isso indica que clientes de fibra óptica podem estar mais insatisfeitos ou mais exigentes, tornando-os mais propensos a cancelar. Já quem não possui internet tende a manter o serviço, talvez por usar apenas telefonia ou por baixo envolvimento com a operadora.
#
# Recomendação: Investigar mais a fundo a experiência dos clientes com fibra óptica para reduzir a evasão nesse segmento.

# %%
df_final['Contract'].describe()
# Out:
# count               7032
# unique                 3
# top       Month-to-month
# freq                3875
# Name: Contract, dtype: object

# %%
print(df_final['Contract'].value_counts())
print(df_final['Contract'].value_counts(normalize=True) * 100)
# Out:
# Contract
# Month-to-month    3875
# Two year          1685
# One year          1472
# Name: count, dtype: int64
# Contract
# Month-to-month    55.105233
# Two year          23.961889
# One year          20.932878
# Name: proportion, dtype: float64

# %%
df_final['Contract'].value_counts()
df_final['Contract'].value_counts(normalize=True) * 100
 # porcentagem
# Out:
# Contract
# Month-to-month    55.105233
# Two year          23.961889
# One year          20.932878
# Name: proportion, dtype: float64

# %%
pd.crosstab(df_final['Contract'], df_final['Churn'])
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1306   166
# Two year        1637    48

# %%
pd.crosstab(df_final['Contract'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %% [markdown]
#  Esses resultados mostram claramente como o tipo de contrato está fortemente associado à evasão de clientes.

# %% [markdown]
# O tipo de contrato está claramente relacionado à retenção de clientes. A maior parte dos cancelamentos ocorre entre clientes com contratos mensais: 42,7% deles cancelaram o serviço.
#
# Em contrapartida, clientes com contrato de um ano apresentaram apenas 11,3% de churn, e os com contrato de dois anos quase não cancelaram: apenas 2,8%.
#
# Isso mostra que contratos mais longos estão fortemente associados à fidelização. Clientes com contratos mensais têm muito mais liberdade para sair, o que pode indicar uma menor confiança ou menor engajamento com a empresa.

# %%
sns.countplot(data=df_final, x='Contract', hue='Churn')
plt.title('Churn por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Número de Clientes')
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %%
df_final['SeniorCitizen'].describe()
# Out:
# count    7032.000000
# mean        0.162400
# std         0.368844
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64

# %%
print(df_final['SeniorCitizen'].value_counts())
print(df_final['SeniorCitizen'].value_counts(normalize=True) * 100)
# Out:
# SeniorCitizen
# 0    5890
# 1    1142
# Name: count, dtype: int64
# SeniorCitizen
# 0    83.759954
# 1    16.240046
# Name: proportion, dtype: float64

# %%
print(pd.crosstab(df_final['SeniorCitizen'], df_final['Churn']))
# Out:
# Churn            No   Yes
# SeniorCitizen
# 0              4497  1393
# 1               666   476

# %%
print(pd.crosstab(df_final['SeniorCitizen'], df_final['Churn'], normalize='index') * 100)
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 0              76.349745  23.650255
# 1              58.318739  41.681261

# %% [markdown]
# Análise do perfil etário (SeniorCitizen)
#
# Apenas 16% dos clientes da base são idosos. No entanto, a taxa de cancelamento nesse grupo é significativamente mais alta do que entre os não idosos:
#
# 41,7% dos clientes idosos cancelaram o serviço.
#
# Contra apenas 23,7% entre os mais jovens.
#
# Isso indica que clientes mais velhos estão mais propensos ao churn — o que pode estar relacionado a fatores como:
#
# Menor adaptação tecnológica,
#
# Maior sensibilidade a preços,
#
# Atendimento menos direcionado a esse público.

# %%
sns.countplot(data=df_final, x='SeniorCitizen' , hue='Churn')
plt.title('Churn por Faixa Etária (Senior Citizen)')
plt.xlabel ('É Idoso? (0 = Não, 1 = Sim)')
plt.ylabel('Número de Clientes')
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %%
# Criar uma tabela com a proporção de churn por grupo SeniorCitizen
prop_churn = pd.crosstab(df_final['SeniorCitizen'], df_final['Churn'], normalize='index') * 100
prop_churn = prop_churn.reset_index()

# Deixar o gráfico no formato "long" para o seaborn
prop_churn_melt = prop_churn.melt(id_vars='SeniorCitizen', var_name='Churn', value_name='Percentual')

# Plotar
plt.figure(figsize=(8,5))
sns.barplot(data=prop_churn_melt, x='SeniorCitizen', y='Percentual', hue='Churn')

plt.title('Proporção de Churn por SeniorCitizen (%)')
plt.xlabel('É Idoso? (0 = Não, 1 = Sim)')
plt.ylabel('Percentual (%)')
plt.ylim(0, 100)
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %%
df_final['gender'].describe()
# Out:
# count     7032
# unique       2
# top       Male
# freq      3549
# Name: gender, dtype: object

# %%
print(df_final['gender'].value_counts())
print(df_final['gender'].value_counts(normalize=True) * 100)
# Out:
# gender
# Male      3549
# Female    3483
# Name: count, dtype: int64
# gender
# Male      50.469283
# Female    49.530717
# Name: proportion, dtype: float64

# %%
print(pd.crosstab(df_final['gender'], df_final['Churn']))
# Out:
# Churn     No  Yes
# gender
# Female  2544  939
# Male    2619  930

# %%
print(pd.crosstab(df_final['gender'], df_final['Churn'], normalize='index') * 100)
# Out:
# Churn          No        Yes
# gender
# Female  73.040482  26.959518
# Male    73.795435  26.204565

# %% [markdown]
# A taxa de churn é ligeiramente maior entre as mulheres (26,96%) do que entre os homens (26,20%).
#
# A diferença é pequena

# %%
df_final['Partner']. describe()
# Out:
# count     7032
# unique       2
# top         No
# freq      3639
# Name: Partner, dtype: object

# %%
# Tabela de contingência: Partner vs Churn
tabela_cruzada = pd.crosstab(df_final['Partner'], df_final['Churn'])
print(tabela_cruzada)
# Out:
# Churn      No   Yes
# Partner
# No       2439  1200
# Yes      2724   669

# %% [markdown]
# Clientes sem parceiro têm uma taxa de churn significativamente maior (33%) do que os que têm parceiro (19,7%).
#
# A diferença é de mais de 13 pontos percentuais.
# Clientes com parceiro podem ter maior estabilidade financeira ou de rotina, o que pode contribuir para a manutenção do serviço.
#
# Já clientes sem parceiro podem estar em situações mais flexíveis ou inconstantes, o que os torna mais propensos a cancelar.
#
# Com base nesses dados, clientes sem parceiro estão mais propensos a cancelar o serviço do que clientes com parceiro. Isso sugere que ter um parceiro pode estar associado a maior estabilidade e menor churn.

# %%
df_final['Dependents']. describe()
# Out:
# count     7032
# unique       2
# top         No
# freq      4933
# Name: Dependents, dtype: object

# %% [markdown]
# A maioria dos clientes não possui dependentes.

# %%
# Tabela de contagem absoluta
pd.crosstab(df_final['Dependents'], df_final['Churn'])
# Out:
# Churn         No   Yes
# Dependents
# No          3390  1543
# Yes         1773   326

# %%
# Tabela percentual (proporção dentro de cada grupo)
pd.crosstab(df_final['Dependents'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn              No        Yes
# Dependents
# No          68.720860  31.279140
# Yes         84.468795  15.531205

# %% [markdown]
# Os dados sugerem que ter dependentes pode estar relacionado com menor chance de cancelamento, talvez por razões como estabilidade familiar, necessidade contínua do serviço ou planejamento financeiro mais estável.

# %%
df_final['PaymentMethod'].describe()
# Out:
# count                 7032
# unique                   4
# top       Electronic check
# freq                  2365
# Name: PaymentMethod, dtype: object

# %%
print(df_final['PaymentMethod'].unique())
# Out:
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %%
pd.crosstab(df_final['PaymentMethod'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.268482  16.731518
# Credit card (automatic)    84.746877  15.253123
# Electronic check           54.714588  45.285412
# Mailed check               80.798005  19.201995

# %% [markdown]
# Clientes que usam métodos automáticos (cartão de crédito ou transferência bancária):
#
# Têm as menores taxas de churn (em torno de 15% a 17%).
#
# Isso pode indicar maior praticidade, compromisso ou estabilidade.
#
# Clientes que usam Electronic check:
#
# Têm a maior taxa de churn, com 45,29% cancelando.
#
# É mais que o dobro dos outros métodos. Isso é um sinal de alerta.
#
# Clientes com Mailed check:
#
# Têm churn um pouco maior (19,2%) que os automáticos, mas bem menor que os de Electronic check.
#
# O método de pagamento está fortemente associado à taxa de cancelamento.
# Clientes que usam Electronic check têm muito mais chance de cancelar.
# Já os que usam pagamento automático (cartão ou transferência) são os mais fiéis.

# %%
# Proporção de churn por método de pagamento (em %)
churn_by_payment = pd.crosstab(df_final['PaymentMethod'], df_final['Churn'], normalize='index') * 100

# Configurar o layout para 2x2 pizzas
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, payment_method in enumerate(churn_by_payment.index):
    data = churn_by_payment.loc[payment_method]
    axes[i].pie(
        data,
        labels=[f'{churn} ({data[churn]:.1f}%)' for churn in data.index],
        autopct='%1.1f%%',
        colors=['green', 'red'],
        startangle=90,
        textprops={'fontsize': 12}
    )
    axes[i].set_title(f'Método de Pagamento: {payment_method}', fontsize=14)

plt.suptitle('Proporção de Churn por Método de Pagamento', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
df_final['PaperlessBilling'].describe()
# Out:
# count     7032
# unique       2
# top        Yes
# freq      4168
# Name: PaperlessBilling, dtype: object

# %%
print(df_final['PaymentMethod'].unique())
# Out:
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %%
df_final['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4168
# No     2864
# Name: count, dtype: int64

# %%
pd.crosstab(df_final['PaymentMethod'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.268482  16.731518
# Credit card (automatic)    84.746877  15.253123
# Electronic check           54.714588  45.285412
# Mailed check               80.798005  19.201995

# %%
payment_churn = {
    'Bank transfer (automatic)': [83.27, 16.73],
    'Credit card (automatic)': [84.75, 15.25],
    'Electronic check': [54.71, 45.29],
    'Mailed check': [80.80, 19.20]
}

fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # 2 linhas, 2 colunas

axes = axes.flatten()  # para iterar facilmente pelos eixos

for ax, (method, values) in zip(axes, payment_churn.items()):
    ax.pie(values, labels=['No', 'Yes'], autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff6666'])
    ax.set_title(f'Churn por método de pagamento\n{method}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Métodos automáticos (transferência bancária e cartão de crédito) apresentam as menores taxas de cancelamento, com cerca de 15% a 17%. Isso indica que clientes que escolhem esses métodos tendem a ser mais fiéis, possivelmente devido à comodidade e ao débito automático que evita atrasos.
#
# Electronic check (cheque eletrônico) tem uma taxa de cancelamento muito alta, cerca de 45%, quase o triplo das opções automáticas. Isso sugere que clientes que utilizam esse método são mais propensos a cancelar o serviço, um alerta para a empresa investigar possíveis causas relacionadas a esse meio de pagamento.
#
# Mailed check (cheque enviado pelo correio) apresenta uma taxa intermediária, com 19% de churn, ainda maior que os métodos automáticos, mas bem abaixo do cheque eletrônico.

# %%
df_final['MultipleLines']. describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      3385
# Name: MultipleLines, dtype: object

# %%
print(df_final['MultipleLines'].unique())
# Out:
# ['No' 'Yes' 'No phone service']

# %%
print(df_final['MultipleLines'].value_counts())
# Out:
# MultipleLines
# No                  3385
# Yes                 2967
# No phone service     680
# Name: count, dtype: int64

# %%
df_multilinhas = df_final[df_final['MultipleLines'] == 'Yes']
churn_multilinhas = df_multilinhas['Churn'].value_counts(normalize=True) * 100
print(churn_multilinhas)
# Out:
# Churn
# No     71.351534
# Yes    28.648466
# Name: proportion, dtype: float64

# %%
df_1linha = df_final[df_final['MultipleLines'] == 'No']
churn_1linha = df_1linha['Churn'].value_counts(normalize=True) * 100
print(churn_1linha)
# Out:
# Churn
# No     74.918759
# Yes    25.081241
# Name: proportion, dtype: float64

# %% [markdown]
# A taxa de churn entre quem tem só uma linha é relativamente baixa, o que indica que esse grupo é mais estável.
#
# Se você comparar com clientes que têm várias linhas, pode perceber diferenças de comportamento.
#
# Clientes com múltiplas linhas têm uma taxa de churn levemente maior do que aqueles com apenas uma linha.
#
# A diferença entre os grupos não é muito grande, mas pode indicar que clientes com múltiplas linhas:
#
# Estão mais expostos a problemas técnicos ou cobranças.
#
# Possuem perfis mais complexos, o que pode aumentar a chance de cancelamento.
#
# Já os clientes com uma única linha mostram maior fidelidade, podendo representar um perfil mais simples e estável de usuário.
#
#  Conclusão:
# Embora a diferença não seja extrema, entender o comportamento de clientes com múltiplas linhas pode ajudar a identificar melhorias no serviço ou em pacotes oferecidos para esse público. Estratégias de retenção específicas podem ser exploradas para esse grupo, como descontos para planos multi-linha ou suporte técnico mais proativo.

# %%
df_final['OnlineSecurity'].describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      3497
# Name: OnlineSecurity, dtype: object

# %%
print(df_final['OnlineSecurity'].unique())
# Out:
# ['No' 'Yes' 'No internet service']

# %%
print(df_final['OnlineSecurity']. value_counts(0))
# Out:
# OnlineSecurity
# No                     3497
# Yes                    2015
# No internet service    1520
# Name: count, dtype: int64

# %%
pd.crosstab(df_final['OnlineSecurity'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                       No        Yes
# OnlineSecurity
# No                   58.221333  41.778667
# No internet service  92.565789   7.434211
# Yes                  85.359801  14.640199

# %% [markdown]
# Clientes com OnlineSecurity = Yes
# Churn: 14,64%
#
# Uma das menores taxas de cancelamento.
#
# Indica que clientes que contratam o serviço de segurança online tendem a manter o serviço, possivelmente por acharem o pacote mais completo ou mais útil.
#
#  Clientes com OnlineSecurity = No
# Churn: 41,78% – quase 3x maior que quem tem o serviço.
#
# Isso é um alerta forte: clientes que não contratam esse serviço estão muito mais propensos a cancelar.
#
# Pode indicar insatisfação, percepção de valor mais baixo ou menos engajamento com os serviços da empresa.
#
# No internet service
# Churn: 7,43% – muito baixa.
#
# Esses clientes não têm internet, e por isso não contrataram segurança online.
#
# Como a maioria não cancela, é possível que sejam clientes de planos mais simples (ex: só telefonia) e estejam satisfeitos ou simplesmente pouco expostos a variações.
#
#
# Há uma forte correlação entre a ausência de OnlineSecurity e alta taxa de churn. Isso pode indicar que:
#
# Oferecer esse serviço aumenta a percepção de valor para o cliente.
#
# A ausência pode estar associada a clientes menos engajados, que veem menos benefícios no serviço e cancelam com mais facilidade.
#
# O que sugerir à empresa?
# Incentivar a adesão ao OnlineSecurity, talvez com testes gratuitos ou pacotes promocionais.
#
# Investigar se a falta de segurança online está ligada à insatisfação ou à falta de conhecimento sobre o serviço.

# %%
df_final['OnlineBackup'].describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      3087
# Name: OnlineBackup, dtype: object

# %%
df_final
# Out:
#      Churn  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       No  Female              0     Yes        Yes       9          Yes
# 1       No    Male              0      No         No       9          Yes
# 2      Yes    Male              0      No         No       4          Yes
# 3      Yes    Male              1     Yes         No      13          Yes
# 4      Yes  Female              1     Yes         No       3          Yes
# ...    ...     ...            ...     ...        ...     ...          ...
# 7262    No  Female              0      No         No      13          Yes
# 7263   Yes    Male              0     Yes         No      22          Yes
# 7264    No    Male              0      No         No       2          Yes
# 7265    No    Male              0     Yes        Yes      67          Yes
# 7266    No    Male              0     Yes        Yes      63           No
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
print(df_final['OnlineBackup'].value_counts())
# Out:
# OnlineBackup
# No                     3087
# Yes                    2425
# No internet service    1520
# Name: count, dtype: int64

# %%
pd.crosstab(df_final['OnlineBackup'], df_final['Churn'], normalize='index') * 100
# Out:
# Churn                       No        Yes
# OnlineBackup
# No                   60.058309  39.941691
# No internet service  92.565789   7.434211
# Yes                  78.432990  21.567010

# %%
# flitrando clientes que não tem internet, não está sendo considerada
df_backup = df_final[
    (df_final['OnlineBackup'] == 'Yes') | (df_final['OnlineBackup'] == 'No')
]

# %%
churn_backup = pd.crosstab(
    df_backup['OnlineBackup'], df_backup['Churn'], normalize='index') * 100
print(churn_backup)
# Out:
# Churn                No        Yes
# OnlineBackup
# No            60.058309  39.941691
# Yes           78.432990  21.567010

# %%
# Dados simulados com base na sua análise (somente clientes com internet)
data = {
    'OnlineBackup': ['Yes', 'No'],
    'Permaneceram': [78.43, 60.06],
    'Cancelaram': [21.57, 39.94]
}

# Criar DataFrame e configurar índice
df_plot = pd.DataFrame(data)
df_plot.set_index('OnlineBackup', inplace=True)

# Criar gráfico de barras
plt.figure(figsize=(8, 5))
df_plot.plot(kind='bar', stacked=False, color=['#66b3ff', '#ff6666'])

plt.title('Churn por uso de OnlineBackup (clientes com internet)')
# Dados simulados com base na sua análise (somente clientes com internet)
data = {
    'OnlineBackup': ['Yes', 'No'],
    'Permaneceram': [78.43, 60.06],
    'Cancelaram': [21.57, 39.94]
}

# Criar DataFrame e configurar índice
df_plot = pd.DataFrame(data)
df_plot.set_index('OnlineBackup', inplace=True)

# Criar gráfico de barras
plt.figure(figsize=(8, 5))
df_plot.plot(kind='bar', stacked=False, color=['#66b3ff', '#ff6666'])

plt.title('Churn por uso de OnlineBackup (clientes com internet)')
plt.xlabel('OnlineBackup')
plt.ylabel('Porcentagem')
plt.xticks(rotation=0)
plt.yticks(np.arange(0, 101, 10))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Status', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# 📊 Interpretação:
# ✅ Clientes que usam OnlineBackup (Yes):
# Apenas 21,57% cancelaram o serviço, ou seja, 78,43% permaneceram.
#
# Isso indica uma alta fidelidade nesse grupo.
#
# A presença do serviço pode aumentar a percepção de valor do pacote.
#
# ❌ Clientes que não usam OnlineBackup (No):
# Quase 40% (39,94%) cancelaram.
#
# Isso representa uma taxa de churn quase o dobro do grupo que contratou o serviço.
#
# Pode refletir menor engajamento ou um pacote menos atrativo.
#
# 🎯 Conclusão:
# Existe uma diferença clara no comportamento de churn entre quem usa e quem não usa o serviço de backup online.
#
# Clientes que contratam OnlineBackup tendem a ser mais fiéis, talvez porque:
#
# Estão mais satisfeitos.
#
# Estão mais engajados com os serviços digitais da empresa.
#
# Já os que não contratam, representam um grupo mais vulnerável ao cancelamento.

# %%
df_final['DeviceProtection'].describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      3094
# Name: DeviceProtection, dtype: object

# %%
print(df_final['DeviceProtection'].unique())
# Out:
# ['No' 'Yes' 'No internet service']

# %%
# Supondo que seu DataFrame seja df_final
# Filtro: apenas clientes com internet (sem "No internet service")
df_dp = df_final[
    (df_final['DeviceProtection'] == 'Yes') |
    (df_final['DeviceProtection'] == 'No')
]

# Tabela de churn normalizada por grupo
churn_dp = pd.crosstab(
    df_dp['DeviceProtection'],
    df_dp['Churn'],
    normalize='index'
) * 100

# Renomeando colunas para facilitar a leitura
churn_dp = churn_dp.rename(columns={'No': 'Permaneceram (%)', 'Yes': 'Cancelaram (%)'})

# Exibir resultado
print(churn_dp)
# Out:
# Churn             Permaneceram (%)  Cancelaram (%)
# DeviceProtection
# No                       60.859729       39.140271
# Yes                      77.460711       22.539289

# %% [markdown]
# Clientes SEM proteção de dispositivo (DeviceProtection = No) têm uma taxa de cancelamento (churn) de 39,14%, ou seja, quase 4 em cada 10 cancelaram o serviço.
#
# Clientes COM proteção de dispositivo (DeviceProtection = Yes) têm uma taxa de cancelamento bem menor, 22,54% — pouco mais de 2 em cada 10.
#
# Insights importantes
# Ter proteção de dispositivo parece estar associado a uma menor taxa de churn, indicando que esse serviço pode ajudar a fidelizar clientes.
#
# A diferença é significativa: clientes sem essa proteção cancelam quase o dobro (39% vs 22%).
#
# Isso sugere que a empresa pode focar em promover esse serviço, pois ele pode contribuir para reduzir a evasão.

# %%
df_final['TechSupport'].describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      3472
# Name: TechSupport, dtype: object

# %%
df_final['TechSupport'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
# Filtrar apenas clientes que têm internet (ou seja, onde TechSupport é 'Yes' ou 'No')
df_ts = df_final[(df_final['TechSupport'] == 'Yes') | (df_final['TechSupport'] == 'No')]

# Calcular taxa de churn para esses grupos
churn_ts = pd.crosstab(
    df_ts['TechSupport'],
    df_ts['Churn'],
    normalize='index'
) * 100

# Renomear colunas para facilitar a leitura
churn_ts = churn_ts.rename(columns={'No': 'Permaneceram (%)', 'Yes': 'Cancelaram (%)'})

# Exibir resultado
print(churn_ts)
# Out:
# Churn        Permaneceram (%)  Cancelaram (%)
# TechSupport
# No                  58.352535       41.647465
# Yes                 84.803922       15.196078

# %% [markdown]
#  Interpretação:
# Clientes que contrataram o suporte técnico (Yes) apresentaram uma baixa taxa de cancelamento, de apenas 15,2%. Isso mostra que esse grupo é muito mais fiel à empresa.
#
# Clientes que não têm suporte técnico (No) cancelaram o serviço em 41,6% dos casos — quase o triplo da taxa de quem tem o serviço.
#
# Conclusão:
# O serviço de suporte técnico está fortemente associado à retenção de clientes.
#
# Ter acesso a suporte técnico pode significar que o cliente:
#
# Recebe ajuda quando enfrenta problemas técnicos, o que melhora a experiência.
#
# Está mais engajado com os serviços digitais.
#
# Enxerga mais valor no pacote oferecido.

# %%
df_final['StreamingTV'].describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      2809
# Name: StreamingTV, dtype: object

# %%
print(df_final['StreamingTV'].unique())
# Out:
# ['Yes' 'No' 'No internet service']

# %%
df_ts = df_final[(df_final['StreamingTV'] == 'Yes') | (df_final['StreamingTV'] == 'No')]

churn_ts = pd.crosstab(
    df_ts['StreamingTV'],
    df_ts['Churn'],
    normalize='index'
) * 100

# Renomear colunas para facilitar a leitura
churn_ts = churn_ts.rename(columns={'No': 'Permaneceram (%)', 'Yes': 'Cancelaram (%)'})

# Exibir resultado
print(churn_ts)
# Out:
# Churn        Permaneceram (%)  Cancelaram (%)
# StreamingTV
# No                  66.464934       33.535066
# Yes                 69.885313       30.114687

# %% [markdown]
# A diferença entre os dois grupos é pequena, mas existe:
#
# Clientes que possuem StreamingTV cancelam um pouco menos (30,11%) do que os que não têm (33,54%).
#
# Isso pode indicar que o serviço de TV por streaming ajuda ligeiramente a reter clientes, mas não é um fator tão decisivo quanto outros (como TechSupport ou DeviceProtection, por exemplo).
#
# O serviço de StreamingTV tem uma leve associação com maior retenção, mas não é determinante.
#
# É possível que esse serviço contribua para o valor percebido do pacote, ajudando a reduzir o churn, mas ele não se destaca fortemente entre os fatores mais impactantes.
#
# A diferença de apenas 3,4 pontos percentuais sugere que talvez o impacto dependa de outros fatores combinados (como tipo de contrato ou presença de outros serviços).

# %%
df_final['StreamingMovies'].describe()
# Out:
# count     7032
# unique       3
# top         No
# freq      2781
# Name: StreamingMovies, dtype: object

# %%
print(df_final['StreamingMovies'].unique())
# Out:
# ['No' 'Yes' 'No internet service']

# %%
df_ts = df_final[(df_final['StreamingMovies'] == 'Yes') | (df_final['StreamingMovies'] == 'No')]

churn_ts = pd.crosstab(
    df_ts['StreamingMovies'],
    df_ts['Churn'],
    normalize='index'
) * 100

# Renomear colunas para facilitar a leitura
churn_ts = churn_ts.rename(columns={'No': 'Permaneceram (%)', 'Yes': 'Cancelaram (%)'})

# Exibir resultado
print(churn_ts)
# Out:
# Churn            Permaneceram (%)  Cancelaram (%)
# StreamingMovies
# No                      66.271125       33.728875
# Yes                     70.047602       29.952398

# %% [markdown]
# Interpretação sobre a relação entre StreamingMovies e Churn
# É importante destacar que a variável StreamingMovies não indica que o cliente cancelou apenas esse serviço, mas sim se ele o utilizava enquanto ainda era cliente da empresa.
#
# O foco da análise é entender se clientes que usavam serviços de filmes por streaming tinham maior ou menor propensão a cancelar o contrato como um todo com a operadora.
#
# A variável StreamingMovies representa se o cliente utilizava o serviço de filmes por streaming. Ao analisar sua relação com o churn (cancelamento total do contrato), observamos que:
#
# Clientes que usavam o serviço apresentaram uma taxa de evasão de 29,95%.
#
# Já os que não utilizavam apresentaram taxa de 33,73%.
#
# Essa diferença, ainda que sutil, sugere que clientes que usam serviços adicionais como o de filmes por streaming estão mais engajados e propensos a permanecer com a empresa. Portanto, serviços complementares podem ser um fator de retenção.

# %%
df_final['Charges.Monthly'].describe()
# Out:
# count    7032.000000
# mean       64.798208
# std        30.085974
# min        18.250000
# 25%        35.587500
# 50%        70.350000
# 75%        89.862500
# max       118.750000
# Name: Charges.Monthly, dtype: float64

# %%
df_final['Charges.Monthly'].unique()
# Out:
# array([65.6 , 59.9 , 73.9 , ..., 91.75, 68.8 , 67.85])

# %%
# Criar as faixas de valor mensal
bins = [0, 40, 80, df_final['Charges.Monthly'].max()]
labels = ['Baixo', 'Médio', 'Alto']
df_final['Charge_Faixa'] = pd.cut(df_final['Charges.Monthly'], bins=bins, labels=labels, right=False)

# Ver a distribuição nas faixas
print(df_final['Charge_Faixa'].value_counts())

# Calcular taxa de churn por faixa
churn_por_faixa = pd.crosstab(df_final['Charge_Faixa'], df_final['Churn'], normalize='index') * 100
print(churn_por_faixa)

# Visualizar com gráfico


churn_por_faixa.plot(kind='bar', stacked=True, figsize=(8,5), color=['#66b3ff', '#ff6666'])
plt.title('Taxa de Churn por Faixa de Valor Mensal')
plt.ylabel('Porcentagem (%)')
plt.xlabel('Faixa de Cobrança Mensal')
plt.legend(title='Churn')
plt.show()
# Out:
# Charge_Faixa
# Alto     2675
# Médio    2525
# Baixo    1831
# Name: count, dtype: int64
# Churn                No        Yes
# Charge_Faixa
# Baixo         88.367013  11.632987
# Médio         70.455446  29.544554
# Alto          65.981308  34.018692

# %% [markdown]
# O que isso significa?
# Clientes com cobrança mensal baixa têm uma taxa de churn muito menor (apenas 11,6%). Ou seja, eles permanecem mais fiéis.
#
# Na faixa média, a taxa de churn aumenta consideravelmente para quase 30%. Isso indica que clientes que pagam valores medianos estão mais propensos a cancelar.
#
# Na faixa alta, o churn é ainda maior (34%), ou seja, o risco de evasão aumenta junto com o valor da cobrança mensal.
#
# Insights:
# Clientes que pagam mais têm maior probabilidade de cancelar — pode ser por insatisfação, custo-benefício, ou outras razões.
#
# Vale a pena investigar por que os clientes de faixas média e alta estão cancelando mais — pode ser necessário melhorar o serviço ou oferecer descontos para essas categorias.

# %%
df_final['Charges.Total'].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: Charges.Total, dtype: float64

# %%
df_final['Charges.Total'].unique()
# Out:
# array([ 593.3 ,  542.4 ,  280.85, ...,  742.9 , 4627.65, 3707.6 ])

# %% [markdown]
# A cobrança total mostra alta dispersão — isso faz sentido, pois clientes com mais tempo de contrato acumulam cobranças maiores.
#
# A mediana (1397,48) é menor que a média (2283,30), o que sugere uma distribuição assimétrica à direita (alguns clientes com valores muito altos puxam a média para cima).
#
# Clientes que pagaram valores totais muito baixos provavelmente estão no início do contrato — pode ser interessante cruzar com a coluna tenure para verificar essa relação.
#
# Valores muito altos indicam clientes de longa data ou com muitos serviços contratados.

# %%
df_final['Charges.Total'].value_counts().head(10)
# Out:
# Charges.Total
# 20.20    11
# 19.75     9
# 19.90     8
# 19.65     8
# 20.05     8
# 45.30     7
# 19.55     7
# 20.15     6
# 20.25     6
# 19.45     6
# Name: count, dtype: int64

# %%
df_final.groupby('Contract')['Charges.Total'].describe()
# Out:
#                  count         mean          std    min      25%      50%  \
# Contract
# Month-to-month  3875.0  1369.254581  1613.879008  18.85   160.10   679.55
# One year        1472.0  3034.683084  2229.730075  18.80   989.35  2657.55
# Two year        1685.0  3728.933947  2571.252806  20.35  1278.80  3623.95
#
#                      75%      max
# Contract
# Month-to-month  2066.500  8061.50
# One year        4859.525  8684.80
# Two year        5999.850  8672.45
